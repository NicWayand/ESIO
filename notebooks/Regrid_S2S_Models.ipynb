# %%
'''

This code is part of the SIPN2 project focused on improving sub-seasonal to seasonal predictions of Arctic Sea Ice. 
If you use this code for a publication or presentation, please cite the reference in the README.md on the
main page (https://github.com/NicWayand/ESIO). 

Questions or comments should be addressed to nicway@uw.edu

Copyright (c) 2018 Nic Wayand

GNU General Public License v3.0


'''
# S2S and C3S Model Regrid

# - Loads in all daily forecasts of sea ice extent
# - Regrids to polar stereographic,
# - Saves to netcdf files grouped by year
# Out:
# '\n\nThis code is part of the SIPN2 project focused on improving sub-seasonal to seasonal predictions of Arctic Sea Ice. \nIf you use this code for a publication or presentation, please cite the reference in the README.md on the\nmain page (https://github.com/NicWayand/ESIO). \n\nQuestions or comments should be addressed to nicway@uw.edu\n\nCopyright (c) 2018 Nic Wayand\n\nGNU General Public License v3.0\n\n\n'

# %%
# Standard Imports
# %matplotlib inline
# %load_ext autoreload
# %autoreload
import matplotlib
import scipy
import matplotlib.pyplot as plt
import datetime
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import numpy as np
import pandas as pd
import xarray as xr
import xesmf as xe
import os
import re
import glob
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import dask

# ESIO Imports
from esio import EsioData as ed
from esio import import_data

# %%
# General plotting settings
sns.set_style('whitegrid')
sns.set_context("talk", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
E = ed.EsioData.load()
# Directories
all_models = [ 'ecmwfsipn','ukmetofficesipn','bom', 'ncep', 'ukmo', 
              'eccc', 'kma', 'cma', 'ecmwf', 'hcmr', 'isaccnr',
              'jma', 'metreofr'] 
# all_models = [ 'metreofr']
runType='forecast'
updateall = False
cvar = 'sic'
stero_grid_file = E.obs['NSIDC_0051']['grid']

# %%
obs_grid = import_data.load_grid_info(stero_grid_file, model='NSIDC')
# Ensure latitude is within bounds (-90 to 90)
# Have to do this because grid file has 90.000001
obs_grid['lat_b'] = obs_grid.lat_b.where(obs_grid.lat_b < 90, other = 90)

# %%
# Regridding Options
method='nearest_s2d' # ['bilinear', 'conservative', 'nearest_s2d', 'nearest_d2s', 'patch']

# %%
# Store dictionary to convert each model variable names to sipn syntax
var_dic = {}

var_dic['cma'] = {'ICEC_P11_L1_GLL0_avg24h':'sic'}
# 'initial_time0_hours':'init_time',
#                  'lat_0':'lat', 'lon_0':'lon',
#                  'forecast_time0':'fore_time',
# guess it looks like cma
for model in all_models:
    var_dic[model] = var_dic['cma']
# Set models that are different
var_dic['bom'] = {'ICEC_P11_L1_GGA0_avg24h':'sic'}
# 'initial_time0_hours':'init_time',
#                  'lat_0':'lat', 'lon_0':'lon',
#                  'forecast_time0':'fore_time',
# C3S models
var_dic['ukmetofficesipn'] = {'CI_GDS0_SFC':'sic'}
var_dic['ecmwfsipn'] = {'CI_GDS0_SFC':'sic'}

# list of models that have month init times
monthly_init_model = ['ecmwfsipn', 'ukmetofficesipn', 'metreofr']

# %%
## TODO
# - Get lat lon bounds

# %%
def test_plot():
    # Set up plotting info
    cmap_sic = matplotlib.colors.ListedColormap(sns.color_palette("Blues", 10))
    cmap_sic.set_bad(color = 'red')

    # Plot original projection
    plt.figure(figsize=(20,10))
    ax1 = plt.axes(projection=ccrs.PlateCarree())
    ds_p = ds.sic.isel(init_time=0).isel(fore_time=0).isel(ensemble=0)
    ds_p.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
                                     vmin=0, vmax=1,
                                     cmap=matplotlib.colors.ListedColormap(sns.color_palette("Blues", 10)),
                        transform=ccrs.PlateCarree());
    ax1.set_extent([-180, 180, -90, 90], crs=ccrs.PlateCarree())
    gl = ax1.gridlines(crs=ccrs.PlateCarree(), linestyle='-')
    gl.xlabels_bottom = True
    gl.ylabels_left = True
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    ax1.coastlines(linewidth=0.75, color='black', resolution='50m');
    plt.title(model)
    
    # Plot SIC on target projection
    (f, ax1) = ice_plot.polar_axis()
    f.set_size_inches((10,10))
    ds_p = ds.sic.isel(init_time=0).isel(fore_time=0).isel(ensemble=0)
    ds_p.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
                                         transform=ccrs.PlateCarree(),
                                         cmap=cmap_sic)
    ax1.set_title('Orginal Grid')

    # Plot SIC on target projection
    (f, ax1) = ice_plot.polar_axis()
    ds_p2 = var_out.isel(init_time=0).isel(fore_time=0).isel(ensemble=0)
    ds_p2.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
                                         transform=ccrs.PlateCarree(),
                                         cmap=cmap_sic)
    ax1.set_title('Target Grid')

# %%
for model in all_models:
    print('Regridding ', model, '...')

    data_dir = E.model[model][runType]['native']
    data_out = E.model[model][runType]['sipn_nc']
    model_grid_file = E.model[model]['grid']

    all_files = glob.glob(os.path.join(data_dir, '*.grib'))
    print("Found ",len(all_files)," files.")
    if updateall:
        print("Updating all files...")
    else:
        print("Only updating new files")
        
    # Remove any "empty" files (sometimes happends with ecmwf downloads)
    all_files_new = []
    for cf in all_files:
        if os.stat(cf).st_size > 0:
            all_files_new.append(cf)
        else:
            print("Found empty file: ",cf,". Consider deleting or redownloading.")
    all_files = sorted(all_files_new) # Replace and sort

    weights_flag = False # Flag to set up weights have been created


    
    # Load land/sea mask file
    if model_grid_file.split('/')[-1]!='MISSING':
        ds_mask = xr.open_dataset(model_grid_file)
    else:
        ds_mask = None

    # For each file
    for cf in all_files:
        # Check if already imported and skip (unless updateall flag is True)
        # Always import the most recent two months of files (because they get updated)
        f_out = os.path.join(data_out, os.path.basename(cf).split('.')[0]+'_Stereo.nc') # netcdf file out 
        if not updateall:
            if (os.path.isfile(f_out)) & (cf not in all_files[-2:]):
                print("Skipping ", os.path.basename(cf), " already imported.")
                continue # Skip, file already imported

        ds = xr.open_dataset(cf, engine='pynio')
        
        # Some grib files do not have a init_time dim, because its assumed for the month
        if model in monthly_init_model:
            c_coords = list(ds.coords.dims.keys())
            tar_coords = list(filter(re.compile('.*initial_time').match, c_coords))
            if len(tar_coords)==0: # Check if we have no initial_time* coordinate
                print('Adding init_time as decoder failed to get it.....')
                ds.coords['initial_time1_hours'] = datetime.datetime(int(cf.split('.')[0].split('_')[1]), 
                                                              int(cf.split('.')[0].split('_')[2]), 1)
                ds = ds.expand_dims('initial_time1_hours')
        
        # Test we have initial_time0_hours or initial_time1_hours
        if ('initial_time0_hours' not in ds.coords) & ('initial_time1_hours' not in ds.coords):
            print('initial_time... not found in file: ',cf,' Skipping it, need to FIX!!!!!!!!')
            continue

        # Rename variables per esipn guidelines
        ds.rename(var_dic[model], inplace=True);
        # Rename coords
        ds = import_data.rename_coords(ds)

        # Apply masks (if available)
        if ds_mask:
            # land_mask is the fraction of native grid cell that is land
            # (1-land_mask) is fraction ocean
            # Multiply sic by fraction ocean to get actual native grid cell sic
            # Also mask land out where land_mask==1
            ds[cvar] = ds[cvar] * (1 - ds_mask.land_mask.where(ds_mask.land_mask<1))


    #     # Set sic below 0 to 0
    #     if X.sic.min().values < 0:
    #         print("Some negative SIC "+str(X.sic.min().values)+" found in input PIOMAS, setting to 0")
    #         X = X.where(X>=0, other=0)

    #     # Apply model mask
    #     X = X.where(X.imask)
    
        # Check only data from one month (download bug)
        cm = pd.to_datetime(ds.init_time.values).month
        if model not in monthly_init_model:
            if np.diff(cm).max() > 0:
                fm = int(cf.split('.')[0].split('_')[2]) # Target month in file
                print("Found dates outside month, removing...")
                ds = ds.where(xr.DataArray(pd.to_datetime(ds.init_time.values).month==fm,
                                       dims=ds.init_time.dims, coords=ds.init_time.coords), drop=True)

        # Calculate regridding matrix
        regridder = xe.Regridder(ds, obs_grid, method, periodic=True, reuse_weights=weights_flag)
        weights_flag = True # Set true for following loops

        # Add NaNs to empty rows of matrix (forces any target cell with ANY source cells containing NaN to be NaN)
        if method=='conservative':
            print('Removing edge cells that contain source NaN cells, should probably check here')
            regridder = import_data.add_matrix_NaNs(regridder)

        # Regrid variable
        var_out = regridder(ds[cvar])

        # Expand dims
        var_out = import_data.expand_to_sipn_dims(var_out)
        
        #test_plot()

        # # Save regridded to netcdf file
        var_out.to_netcdf(f_out)
        var_out = None # Memory clean up
        ds = None
        print('Saved ', f_out)
        
        
    # End of all files for current model
    # Clean up data from this model
    ds_mask = None

    # Clean up
    if weights_flag:
        regridder.clean_weight_file()  # clean-up
# Out:
# Regridding  ecmwfsipn ...
# Found  237  files.
# Only updating new files
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2006_08.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_01.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_02.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_03.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_04.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_05.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_06.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_07.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_08.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_09.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_10.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_11.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2016_12.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_01.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_02.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_03.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_04.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_05.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_06.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_07.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_08.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_09.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ecmwfsipn/forecast/native/ecmwfsipn_2017_10.grib . Consider deleting or redownloading.
# Skipping  ecmwfsipn_1993_01.grib  already imported.
# Skipping  ecmwfsipn_1993_02.grib  already imported.
# Skipping  ecmwfsipn_1993_03.grib  already imported.
# Skipping  ecmwfsipn_1993_04.grib  already imported.
# Skipping  ecmwfsipn_1993_05.grib  already imported.
# Skipping  ecmwfsipn_1993_06.grib  already imported.
# Skipping  ecmwfsipn_1993_07.grib  already imported.
# Skipping  ecmwfsipn_1993_08.grib  already imported.
# Skipping  ecmwfsipn_1993_09.grib  already imported.
# Skipping  ecmwfsipn_1993_10.grib  already imported.
# Skipping  ecmwfsipn_1993_11.grib  already imported.
# Skipping  ecmwfsipn_1993_12.grib  already imported.
grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/ukmetofficesipn/forecast/native/ukmetofficesipn_2006_08.grib . Consider deleting or redownloading.
# Skipping  ukmetofficesipn_2014_01.grib  already imported.
# Skipping  ukmetofficesipn_2014_02.grib  already imported.
# Skipping  ukmetofficesipn_2014_03.grib  already imported.
# Skipping  ukmetofficesipn_2014_04.grib  already imported.
# Skipping  ukmetofficesipn_2015_01.grib  already imported.
# Skipping  ukmetofficesipn_2015_02.grib  already imported.
# Skipping  ukmetofficesipn_2015_03.grib  already imported.
# Skipping  ukmetofficesipn_2015_04.grib  already imported.
# Skipping  ukmetofficesipn_2018_01.grib  already imported.
# Skipping  ukmetofficesipn_2018_02.grib  already imported.
# Skipping  ukmetofficesipn_2018_03.grib  already imported.
# Skipping  ukmetofficesipn_2018_04.grib  already imported.
# Create weight file: nearest_s2d_180x360_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ukmetofficesipn/forecast/sipn_nc/ukmetofficesipn_2018_05_Stereo.nc
# Adding init_time as decoder failed to get it.....
# Reuse existing file: nearest_s2d_180x360_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ukmetofficesipn/forecast/sipn_nc/ukmetofficesipn_2018_06_Stereo.nc
# Remove file nearest_s2d_180x360_304x448_peri.nc
# Regridding  bom ...
# Found  42  files.
# Only updating new files
# Skipping  bom_2015_01.grib  already imported.
# Skipping  bom_2015_02.grib  already imported.
# Skipping  bom_2015_03.grib  already imported.
# Skipping  bom_2015_04.grib  already imported.
# Skipping  bom_2015_05.grib  already imported.
# Skipping  bom_2015_06.grib  already imported.
# Skipping  bom_2015_07.grib  already imported.
# Skipping  bom_2015_08.grib  already imported.
# Skipping  bom_2015_09.grib  already imported.
# Skipping  bom_2015_10.grib  already imported.
# Skipping  bom_2015_11.grib  already imported.
# Skipping  bom_2015_12.grib  already imported.
# Skipping  bom_2016_01.grib  already imported.
# Skipping  bom_2016_02.grib  already imported.
# Skipping  bom_2016_03.grib  already imported.
# Skipping  bom_2016_04.grib  already imported.
# Skipping  bom_2016_05.grib  already imported.
# Skipping  bom_2016_06.grib  already imported.
# Skipping  bom_2016_07.grib  already imported.
# Skipping  bom_2016_08.grib  already imported.
# Skipping  bom_2016_09.grib  already imported.
# Skipping  bom_2016_10.grib  already imported.
# Skipping  bom_2016_11.grib  already imported.
# Skipping  bom_2016_12.grib  already imported.
# Skipping  bom_2017_01.grib  already imported.
# Skipping  bom_2017_02.grib  already imported.
# Skipping  bom_2017_03.grib  already imported.
# Skipping  bom_2017_04.grib  already imported.
# Skipping  bom_2017_05.grib  already imported.
# Skipping  bom_2017_06.grib  already imported.
# Skipping  bom_2017_07.grib  already imported.
# Skipping  bom_2017_08.grib  already imported.
# Skipping  bom_2017_09.grib  already imported.
# Skipping  bom_2017_10.grib  already imported.
# Skipping  bom_2017_11.grib  already imported.
# Skipping  bom_2017_12.grib  already imported.
# Skipping  bom_2018_01.grib  already imported.
# Skipping  bom_2018_02.grib  already imported.
# Skipping  bom_2018_03.grib  already imported.
# Skipping  bom_2018_04.grib  already imported.
# Create weight file: nearest_s2d_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2018_05_Stereo.nc
# Reuse existing file: nearest_s2d_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model
# Skipping  ukmo_2017_02.grib  already imported.
# Skipping  ukmo_2017_03.grib  already imported.
# Skipping  ukmo_2017_04.grib  already imported.
# Skipping  ukmo_2017_05.grib  already imported.
# Skipping  ukmo_2017_06.grib  already imported.
# Skipping  ukmo_2017_07.grib  already imported.
# Skipping  ukmo_2017_08.grib  already imported.
# Skipping  ukmo_2017_09.grib  already imported.
# Skipping  ukmo_2017_10.grib  already imported.
# Skipping  ukmo_2017_11.grib  already imported.
# Skipping  ukmo_2017_12.grib  already imported.
# Skipping  ukmo_2018_01.grib  already imported.
# Skipping  ukmo_2018_02.grib  already imported.
# Skipping  ukmo_2018_03.grib  already imported.
# Skipping  ukmo_2018_04.grib  already imported.
# Create weight file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ukmo/forecast/sipn_nc/ukmo_2018_05_Stereo.nc
# Reuse existing file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ukmo/forecast/sipn_nc/ukmo_2018_06_Stereo.nc
# Remove file nearest_s2d_121x240_304x448_peri.nc
# Regridding  eccc ...
# Found  42  files.
# Only updating new files
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_01.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_02.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_03.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_04.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_05.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_06.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_07.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_08.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_09.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_10.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_11.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2015_12.grib . Consider deleting or redownloading.
# Skipping  eccc_2016_01.grib  already imported.
# Skipping  eccc_2016_02.grib  already imported.
# Skipping  eccc_2016_03.grib  already imported.
# Skipping  eccc_2016_04.grib  already imported.
# Skipping  eccc_2016_05.grib  already imported.
# Skipping  eccc_2016_06.grib  already imported.
# Skipping  eccc_2016_07.grib  already imported.
# Skipping  eccc_2016_08.grib  already imported.
# Skipping  eccc_2016_09.grib  already imported.
# Skipping  eccc_2016_10.grib  already imported.
# Skipping  eccc_2016_11.grib  already imported.
# Skipping  eccc_2016_12.grib  already imported.
# Skipping  eccc_2017_01.grib  already imported.
# Skipping  eccc_2017_02.grib  already imported.
# Skipping  eccc_2017_03.grib  already imported.
# Skipping  eccc_2017_04.grib  already imported.
# Skipping  eccc_2017_05.grib  already imported.
# Skipping  eccc_2017_06.grib  already imported.
# Skipping  eccc_2017_07.grib  already imported.
# Skipping  eccc_2017_08.grib  already imported.
# Skipping  eccc_2017_09.grib  already imported.
# Skipping  eccc_2017_10.grib  already imported.
# Skipping  eccc_2017_11.grib  already imported.
# Skipping  eccc_2017_12.grib  already imported.
# Skipping  eccc_2018_01.grib  already imported.
# Skipping  eccc_2018_02.grib  already imported.
# Skipping  eccc_2018_03.grib  already imported.
# Skipping  eccc_2018_04.grib  already imported.
# Create weight file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/eccc/forecast/sipn_nc/eccc_2018_05_Stereo.nc
# initial_time... not found in file:  /home/disk/sipn/nicway/data/model/eccc/forecast/native/eccc_2018_06.grib  Skipping it, need to FIX!!!!!!!!
# Remove file nearest_s2d_121x240_304x448_peri.nc
# Regridding  kma ...
# Found  42  files.
# Only updating new files
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_01.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_02.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_03.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_04.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_05.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_06.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_07.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_08.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_09.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_10.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_11.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2015_12.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_01.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_02.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_03.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_04.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_05.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_06.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_07.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_08.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_09.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/kma/forecast/native/kma_2016_10.grib . Consider deleting or redownloading.
# Skipping  kma_2016_11.grib  already imported.
# Skipping  kma_2016_12.grib  already imported.
# Skipping  kma_2017_01.grib  already imported.
# Skipping  kma_2017_02.grib  already imported.
# Skipping  kma_2017_03.grib  already imported.
# Skipping  kma_2017_04.grib  already imported.
# Skipping  kma_2017_05.grib  already imported.
# Skipping  kma_2017_06.grib  already imported.
# Skipping  kma_2017_07.grib  already imported.
# Skipping  kma_2017_08.grib  already imported.
# Skipping  kma_2017_09.grib  already imported.
# Skipping  kma_2017_10.grib  already imported.
# Skipping  kma_2017_11.grib  already imported.
# Skipping  kma_2017_12.grib  already imported.
# Skipping  kma_2018_01.grib  already imported.
# Skipping  kma_2018_02.grib  already imported.
# Skipping  kma_2018_03.grib  already imported.
# Skipping  kma_2018_04.grib  already imported.
# Create weight file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2018_05_Stereo.nc
# Reuse existing file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2018_06_Stereo.nc
# Remove file nearest_s2d_121x240_304x448_peri.nc
# Regridding  cma ...
# Found  42  files.
# Only updating new files
# Skipping  cma_2015_01.grib  already imported.
# Skipping  cma_2015_02.grib  already imported.
# Skipping  cma_2015_03.grib  already imported.
# Skipping  cma_2015_04.grib  already imported.
# Skipping  cma_2015_05.grib  already imported.
# Skipping  cma_2015_06.grib  already imported.
# Skipping  cma_2015_07.grib  already imported.
# Skipping  cma_2015_08.grib  already imported.
# Skipping  cma_2015_09.grib  already imported.
# Skipping  cma_2015_10.grib  already imported.
# Skipping  cma_2015_11.grib  already imported.
# Skipping  cma_2015_12.grib  already imported.
# Skipping  cma_2016_01.grib  already imported.
# Skipping  cma_2016_02.grib  already imported.
# Skipping  cma_2016_03.grib  already imported.
# Skipping  cma_2016_04.grib  already imported.
# Skipping  cma_2016_05.grib  already imported.
# Skipping  cma_2016_06.grib  already imported.
# Skipping  cma_2016_07.grib  already imported.
# Skipping  cma_2016_08.grib  already imported.
# Skipping  cma_2016_09.grib  already imported.
# Skipping  cma_2016_10.grib  already imported.
# Skipping  cma_2016_11.grib  already imported.
# Skipping  cma_2016_12.grib  already imported.
# Skipping  cma_2017_01.grib  already imported.
# Skipping  cma_2017_02.grib  already imported.
# Skipping  cma_2017_03.grib  already imported.
# Skipping  cma_2017_04.grib  already imported.
# Skipping  cma_2017_05.grib  already imported.
# Skipping  cma_2017_06.grib  already imported.
# Skipping  cma_2017_07.grib  already imported.
# Skipping  cma_2017_08.grib  already imported.
# Skipping  cma_2017_09.grib  already imported.
# Skipping  cma_2017_10.grib  already imported.
# Skipping  cma_2017_11.grib  already imported.
# Skipping  cma_2017_12.grib  already imported.
# Skipping  cma_2018_01.grib  already imported.
# Skipping  cma_2018_02.grib  already imported.
# Skipping  cma_2018_03.grib  already imported.
# Skipping  cma_2018_04.grib  already imported.
# Create weight file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2018_05_Stereo.nc
# Reuse existing file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2018_06_Stereo.nc
# Remove file nearest_s2d_121x240_304x448_peri.nc
# Regridding  ecmwf ...
# Found  42  files.
# Only updating new files
# Skipping  ecmwf_2015_01.grib  already imported.
# Skipping  ecmwf_2015_02.grib  already imported.
# Skipping  ecmwf_2015_03.grib  already imported.
# Skipping  ecmwf_2015_04.grib  already imported.
# Skipping  ecmwf_2015_05.grib  already imported.
# Skipping  ecmwf_2015_06.grib  already imported.
# Skipping  ecmwf_2015_07.grib  already imported.
# Skipping  ecmwf_2015_08.grib  already imported.
# Skipping  ecmwf_2015_09.grib  already imported.
# Skipping  ecmwf_2015_10.grib  already imported.
# Skipping  ecmwf_2015_11.grib  already imported.
# Skipping  ecmwf_2015_12.grib  already imported.
# Skipping  ecmwf_2016_01.grib  already imported.
# Skipping  ecmwf_2016_02.grib  already imported.
# Skipping  ecmwf_2016_03.grib  already imported.
# Skipping  ecmwf_2016_04.grib  already imported.
# Skipping  ecmwf_2016_05.grib  already imported.
# Skipping  ecmwf_2016_06.grib  already imported.
# Skipping  ecmwf_2016_07.grib  already imported.
# Skipping  ecmwf_2016_08.grib  already imported.
# Skipping  ecmwf_2016_09.grib  already imported.
# Skipping  ecmwf_2016_10.grib  already imported.
# Skipping  ecmwf_2016_11.grib  already imported.
# Skipping  ecmwf_2016_12.grib  already imported.
# Skipping  ecmwf_2017_01.grib  already imported.
# Skipping  ecmwf_2017_02.grib  already imported.
# Skipping  ecmwf_2017_03.grib  already imported.
# Skipping  ecmwf_2017_04.grib  already imported.
# Skipping  ecmwf_2017_05.grib  already imported.
# Skipping  ecmwf_2017_06.grib  already imported.
# Skipping  ecmwf_2017_07.grib  already imported.
# Skipping  ecmwf_2017_08.grib  already imported.
# Skipping  ecmwf_2017_09.grib  already imported.
# Skipping  ecmwf_2017_10.grib  already imported.
# Skipping  ecmwf_2017_11.grib  already imported.
# Skipping  ecmwf_2017_12.grib  already imported.
# Skipping  ecmwf_2018_01.grib  already imported.
# Skipping  ecmwf_2018_02.grib  already imported.
# Skipping  ecmwf_2018_03.grib  already imported.
# Skipping  ecmwf_2018_04.grib  already imported.
# Create weight file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2018_05_Stereo.nc
# Reuse existing file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2018_06_Stereo.nc
# Remove file nearest_s2d_121x240_304x448_peri.nc
# Regridding  hcmr ...
# Found  42  files.
# Only updating new files
# Skipping  hcmr_2015_01.grib  already imported.
# Skipping  hcmr_2015_02.grib  already imported.
# Skipping  hcmr_2015_03.grib  already imported.
# Skipping  hcmr_2015_04.grib  already imported.
# Skipping  hcmr_2015_05.grib  already imported.
# Skipping  hcmr_2015_06.grib  already imported.
# Skipping  hcmr_2015_07.grib  already imported.
# Skipping  hcmr_2015_08.grib  already imported.
# Skipping  hcmr_2015_09.grib  already imported.
# Skipping  hcmr_2015_10.grib  already imported.
# Skipping  hcmr_2015_11.grib  already imported.
# Skipping  hcmr_2015_12.grib  already imported.
# Skipping  hcmr_2016_01.grib  already imported.
# Skipping  hcmr_2016_02.grib  already imported.
# Skipping  hcmr_2016_03.grib  already imported.
# Skipping  hcmr_2016_04.grib  already imported.
# Skipping  hcmr_2016_05.grib  already imported.
# Skipping  hcmr_2016_06.grib  already imported.
# Skipping  hcmr_2016_07.grib  already imported.
# Skipping  hcmr_2016_08.grib  already imported.
# Skipping  hcmr_2016_09.grib  already imported.
# Skipping  hcmr_2016_10.grib  already imported.
# Skipping  hcmr_2016_11.grib  already imported.
# Skipping  hcmr_2016_12.grib  already imported.
# Skipping  hcmr_2017_01.grib  already imported.
# Skipping  hcmr_2017_02.grib  already imported.
# Skipping  hcmr_2017_03.grib  already imported.
# Skipping  hcmr_2017_04.grib  already imported.
# Skipping  hcmr_2017_05.grib  already imported.
# Skipping  hcmr_2017_06.grib  already imported.
# Skipping  hcmr_2017_07.grib  already imported.
# Skipping  hcmr_2017_08.grib  already imported.
# Skipping  hcmr_2017_09.grib  already imported.
# Skipping  hcmr_2017_10.grib  already imported.
# Skipping  hcmr_2017_11.grib  already imported.
# Skipping  hcmr_2017_12.grib  already imported.
# Skipping  hcmr_2018_01.grib  already imported.
# Skipping  hcmr_2018_02.grib  already imported.
# Skipping  hcmr_2018_03.grib  already imported.
# Skipping  hcmr_2018_04.grib  already imported.
# Create weight file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2018_05_Stereo.nc
# initial_time... not found in file:  /home/disk/sipn/nicway/data/model/hcmr/forecast/native/hcmr_2018_06.grib  Skipping it, need to FIX!!!!!!!!
# Remove file nearest_s2d_121x240_304x448_peri.nc
# Regridding  isaccnr ...
# Found  32  files.
# Only updating new files
# Skipping  isaccnr_2015_11.grib  already imported.
# Skipping  isaccnr_2015_12.grib  already imported.
# Skipping  isaccnr_2016_01.grib  already imported.
# Skipping  isaccnr_2016_02.grib  already imported.
# Skipping  isaccnr_2016_03.grib  already imported.
# Skipping  isaccnr_2016_04.grib  already imported.
# Skipping  isaccnr_2016_05.grib  already imported.
# Skipping  isaccnr_2016_06.grib  already imported.
# Skipping  isaccnr_2016_07.grib  already imported.
# Skipping  isaccnr_2016_08.grib  already imported.
# Skipping  isaccnr_2016_09.grib  already imported.
# Skipping  isaccnr_2016_10.grib  already imported.
# Skipping  isaccnr_2016_11.grib  already imported.
# Skipping  isaccnr_2016_12.grib  already imported.
# Skipping  isaccnr_2017_01.grib  already imported.
# Skipping  isaccnr_2017_02.grib  already imported.
# Skipping  isaccnr_2017_03.grib  already imported.
# Skipping  isaccnr_2017_04.grib  already imported.
# Skipping  isaccnr_2017_05.grib  already imported.
# Skipping  isaccnr_2017_06.grib  already imported.
# Skipping  isaccnr_2017_07.grib  already imported.
# Skipping  isaccnr_2017_08.grib  already imported.
# Skipping  isaccnr_2017_09.grib  already imported.
# Skipping  isaccnr_2017_10.grib  already imported.
# Skipping  isaccnr_2017_11.grib  already imported.
# Skipping  isaccnr_2017_12.grib  already imported.
# Skipping  isaccnr_2018_01.grib  already imported.
# Skipping  isaccnr_2018_02.grib  already imported.
# Skipping  isaccnr_2018_03.grib  already imported.
# Skipping  isaccnr_2018_04.grib  already imported.
# Create weight file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/isaccnr/forecast/sipn_nc/isaccnr_2018_05_Stereo.nc
# initial_time... not found in file:  /home/disk/sipn/nicway/data/model/isaccnr/forecast/native/isaccnr_2018_06.grib  Skipping it, need to FIX!!!!!!!!
# Remove file nearest_s2d_121x240_304x448_peri.nc
# Regridding  jma ...
# Found  42  files.
# Only updating new files
# Skipping  jma_2015_01.grib  already imported.
# Skipping  jma_2015_02.grib  already imported.
# Skipping  jma_2015_03.grib  already imported.
# Skipping  jma_2015_04.grib  already imported.
# Skipping  jma_2015_05.grib  already imported.
# Skipping  jma_2015_06.grib  already imported.
# Skipping  jma_2015_07.grib  already imported.
# Skipping  jma_2015_08.grib  already imported.
# Skipping  jma_2015_09.grib  already imported.
# Skipping  jma_2015_10.grib  already imported.
# Skipping  jma_2015_11.grib  already imported.
# Skipping  jma_2015_12.grib  already imported.
# Skipping  jma_2016_01.grib  already imported.
# Skipping  jma_2016_02.grib  already imported.
# Skipping  jma_2016_03.grib  already imported.
# Skipping  jma_2016_04.grib  already imported.
# Skipping  jma_2016_05.grib  already imported.
# Skipping  jma_2016_06.grib  already imported.
# Skipping  jma_2016_07.grib  already imported.
# Skipping  jma_2016_08.grib  already imported.
# Skipping  jma_2016_09.grib  already imported.
# Skipping  jma_2016_10.grib  already imported.
# Skipping  jma_2016_11.grib  already imported.
# Skipping  jma_2016_12.grib  already imported.
# Skipping  jma_2017_01.grib  already imported.
# Skipping  jma_2017_02.grib  already imported.
# Skipping  jma_2017_03.grib  already imported.
# Skipping  jma_2017_04.grib  already imported.
# Skipping  jma_2017_05.grib  already imported.
# Skipping  jma_2017_06.grib  already imported.
# Skipping  jma_2017_07.grib  already imported.
# Skipping  jma_2017_08.grib  already imported.
# Skipping  jma_2017_09.grib  already imported.
# Skipping  jma_2017_10.grib  already imported.
# Skipping  jma_2017_11.grib  already imported.
# Skipping  jma_2017_12.grib  already imported.
# Skipping  jma_2018_01.grib  already imported.
# Skipping  jma_2018_02.grib  already imported.
# Skipping  jma_2018_03.grib  already imported.
# Skipping  jma_2018_04.grib  already imported.
# Create weight file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/jma/forecast/sipn_nc/jma_2018_05_Stereo.nc
# initial_time... not found in file:  /home/disk/sipn/nicway/data/model/jma/forecast/native/jma_2018_06.grib  Skipping it, need to FIX!!!!!!!!
# Remove file nearest_s2d_121x240_304x448_peri.nc
# Regridding  metreofr ...
# Found  42  files.
# Only updating new files
# Found empty file:  /home/disk/sipn/nicway/data/model/metreofr/forecast/native/metreofr_2015_01.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/metreofr/forecast/native/metreofr_2015_02.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/metreofr/forecast/native/metreofr_2015_03.grib . Consider deleting or redownloading.
# Found empty file:  /home/disk/sipn/nicway/data/model/metreofr/forecast/native/metreofr_2015_04.grib . Consider deleting or redownloading.
# Skipping  metreofr_2015_05.grib  already imported.
# Skipping  metreofr_2015_06.grib  already imported.
# Skipping  metreofr_2015_07.grib  already imported.
# Skipping  metreofr_2015_08.grib  already imported.
# Skipping  metreofr_2015_09.grib  already imported.
# Skipping  metreofr_2015_10.grib  already imported.
# Skipping  metreofr_2015_11.grib  already imported.
# Skipping  metreofr_2015_12.grib  already imported.
# Skipping  metreofr_2016_01.grib  already imported.
# Skipping  metreofr_2016_02.grib  already imported.
# Skipping  metreofr_2016_03.grib  already imported.
# Skipping  metreofr_2016_04.grib  already imported.
# Skipping  metreofr_2016_05.grib  already imported.
# Skipping  metreofr_2016_06.grib  already imported.
# Skipping  metreofr_2016_07.grib  already imported.
# Skipping  metreofr_2016_08.grib  already imported.
# Skipping  metreofr_2016_09.grib  already imported.
# Skipping  metreofr_2016_10.grib  already imported.
# Skipping  metreofr_2016_11.grib  already imported.
# Skipping  metreofr_2016_12.grib  already imported.
# Skipping  metreofr_2017_01.grib  already imported.
# Skipping  metreofr_2017_02.grib  already imported.
# Skipping  metreofr_2017_03.grib  already imported.
# Skipping  metreofr_2017_04.grib  already imported.
# Skipping  metreofr_2017_05.grib  already imported.
# Skipping  metreofr_2017_06.grib  already imported.
# Skipping  metreofr_2017_07.grib  already imported.
# Skipping  metreofr_2017_08.grib  already imported.
# Skipping  metreofr_2017_09.grib  already imported.
# Skipping  metreofr_2017_10.grib  already imported.
# Skipping  metreofr_2017_11.grib  already imported.
# Skipping  metreofr_2017_12.grib  already imported.
# Skipping  metreofr_2018_01.grib  already imported.
# Skipping  metreofr_2018_02.grib  already imported.
# Skipping  metreofr_2018_03.grib  already imported.
# Skipping  metreofr_2018_04.grib  already imported.
# Create weight file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/metreofr/forecast/sipn_nc/metreofr_2018_05_Stereo.nc
# Adding init_time as decoder failed to get it.....
# Reuse existing file: nearest_s2d_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/metreofr/forecast/sipn_nc/metreofr_2018_06_Stereo.nc
# Remove file nearest_s2d_121x240_304x448_peri.nc

# %%
# cmap_sic = matplotlib.colors.ListedColormap(sns.color_palette("Blues", 10))
# cmap_sic.set_bad(color = 'red')


# # Plot SIC on target projection
# (f, ax1) = ice_plot.polar_axis()
# f.set_size_inches((10,10))
# ds_mask.land_mask.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
#                                      transform=ccrs.PlateCarree(),
#                                      cmap='Blues')

# %%
# cmap_sic = matplotlib.colors.ListedColormap(sns.color_palette("Blues", 10))
# cmap_sic.set_bad(color = 'red')


# # # Plot SIC on target projection
# # (f, ax1) = ice_plot.polar_axis()
# # f.set_size_inches((10,10))
# # ds_mask.land_mask.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
# #                                      transform=ccrs.PlateCarree(),
# #                                      cmap='Blues')

# # # Plot SIC on target projection
# # (f, ax1) = ice_plot.polar_axis()
# # f.set_size_inches((10,10))
# # mask_out.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
# #                                      transform=ccrs.PlateCarree(),
# #                                      cmap='Blues')

# # Plot SIC on target projection
# (f, ax1) = ice_plot.polar_axis()
# f.set_size_inches((10,10))
# ds_p = ds.sic.isel(init_time=0).isel(fore_time=0).isel(ensemble=0)
# ds_p.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
#                                      transform=ccrs.PlateCarree(),
#                                      cmap=cmap_sic)
# ax1.set_title('Orginal Grid')

# # Plot SIC on target projection
# (f, ax1) = ice_plot.polar_axis()
# f.set_size_inches((10,10))
# ds_p2 = var_out.isel(init_time=0).isel(fore_time=0).isel(ensemble=0)
# ds_p2.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
#                                      transform=ccrs.PlateCarree(),
#                                      cmap=cmap_sic)
# ax1.set_title('Target Grid')

# %%
# # Plot SIC on target projection
# (f, ax1) = ice_plot.polar_axis()
# f.set_size_inches((10,10))
# (1 - ds_mask.land_mask.where(ds_mask.land_mask<1)).plot.pcolormesh(ax=ax1, x='lon', y='lat', 
#                                      transform=ccrs.PlateCarree(),
#                                      cmap=cmap_sic)
# ax1.set_title('mask we use')
