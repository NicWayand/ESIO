# %%
# S2S Model Regrid

# - Loads in all daily forecasts of sea ice extent
# - Regrids to polar stereographic,
# - Saves to netcdf files grouped by year

# %%
# Standard Imports
# %matplotlib inline
# %load_ext autoreload
# %autoreload
import matplotlib
import scipy
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import numpy as np
import pandas as pd
import xarray as xr
import xesmf as xe
import os
import glob
import seaborn as sns
import warnings

# ESIO Imports
import esio
import esiodata as ed

# %%
# General plotting settings
sns.set_style('whitegrid')
sns.set_context("talk", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
E = ed.esiodata.load()
# Directories
all_models = ['bom', 'cma', 'ecmwf', 'hcmr', 'isaccnr',
          'jma', 'metreofr', 'ncep', 'ukmo', 'eccc', 'kma']
runType='forecast'
updateall = True

stero_grid_file = E.obs['NSIDC_0051']['grid']

# %%
obs_grid = esio.load_grid_info(stero_grid_file, model='NSIDC')
# Ensure latitude is within bounds (-90 to 90)
# Have to do this because grid file has 90.000001
obs_grid['lat_b'] = obs_grid.lat_b.where(obs_grid.lat_b < 90, other = 90)

# %%
# Regridding Options
method='bilinear' # ['bilinear', 'conservative', 'nearest_s2d', 'nearest_d2s', 'patch']

# %%
# Store dictionary to convert each model variable names to sipn syntax
var_dic = {}

var_dic['cma'] = {'initial_time0_hours':'init_time',
                 'lat_0':'lat', 'lon_0':'lon',
                 'forecast_time0':'fore_time',
                 'ICEC_P11_L1_GLL0_avg24h':'sic'}
# guess it looks like cma
for model in all_models:
    var_dic[model] = var_dic['cma']
# Set models that are different
var_dic['bom'] = {'initial_time0_hours':'init_time',
                 'lat_0':'lat', 'lon_0':'lon',
                 'forecast_time0':'fore_time',
                 'ICEC_P11_L1_GGA0_avg24h':'sic'}

# %%
## TODO
# - Get mask
# - Get lat lon bounds

# %%
def test_plot():
    # Set up plotting info
    cmap_sic = matplotlib.colors.ListedColormap(sns.color_palette("Blues", 10))
    cmap_sic.set_bad(color = 'red')

    # Plot original projection
    plt.figure(figsize=(20,10))
    ax1 = plt.axes(projection=ccrs.PlateCarree())
    ds_p = ds.sic.isel(init_time=0).isel(fore_time=0)
    ds_p.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
                                     vmin=0, vmax=1,
                                     cmap=matplotlib.colors.ListedColormap(sns.color_palette("Blues", 10)),
                        transform=ccrs.PlateCarree());
    ax1.set_extent([-180, 180, -90, 90], crs=ccrs.PlateCarree())
    gl = ax1.gridlines(crs=ccrs.PlateCarree(), linestyle='-')
    gl.xlabels_bottom = True
    gl.ylabels_left = True
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    ax1.coastlines(linewidth=0.75, color='black', resolution='50m');
    plt.title(model)

    # Plot SIC on target projection
    (f, ax1) = esio.polar_axis()
    ds_p2 = var_out.isel(init_time=0).isel(fore_time=0).isel(ensemble=0)
    ds_p2.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
                                         transform=ccrs.PlateCarree(),
                                         cmap=cmap_sic)
    ax1.set_title('Target Grid')

# %%
for model in all_models:
    print('Regridding ', model, '...')

    data_dir = E.model[model][runType]['native']
    data_out = E.model[model][runType]['sipn_nc']
    model_grid_file = E.model[model]['grid']

    all_files = glob.glob(os.path.join(data_dir, '*.grib'))
    print("Found ",len(all_files)," files.")
    if updateall:
        print("Updating all files...")
    else:
        print("Only updating new files")

    weights_flag = False # Flag to set up weights have been created

    cvar = 'sic'

    for cf in all_files:
        # Check if already imported and skip (unless updateall flag is True)
        f_out = os.path.join(data_out, os.path.basename(cf).split('.')[0]+'_Stereo.nc') # netcdf file out 
        if not updateall:
            if os.path.isfile(f_out):
                print("Skipping ", os.path.basename(cf), " already imported.")
                continue # Skip, file already imported

        ds = xr.open_dataset(cf, engine='pynio')

        # Rename variables per esipn guidelines
        ds.rename(var_dic[model], inplace=True);

    #     ds.coords['nj'] = model_grid.nj
    #     ds.coords['ni'] = model_grid.ni
    #     ds.coords['lat'] = model_grid.lat
    #     ds.coords['lon'] = model_grid.lon
    #     ds.coords['lat_b'] = model_grid.lat_b
    #     ds.coords['lon_b'] = model_grid.lon_b
    #     ds.coords['imask'] = model_grid.imask

    #     # Set sic below 0 to 0
    #     if X.sic.min().values < 0:
    #         print("Some negative SIC "+str(X.sic.min().values)+" found in input PIOMAS, setting to 0")
    #         X = X.where(X>=0, other=0)

    #     # Apply model mask
    #     X = X.where(X.imask)
    
        print("HACK to remove init_time not inside this current month")
        cm = pd.to_datetime(ds.init_time.values[0]).month
        ds = ds.where(xr.DataArray(pd.to_datetime(ds.init_time.values).month==cm, dims=ds.init_time.dims, coords=ds.init_time.coords), drop=True)

        # Calculate regridding matrix
        regridder = xe.Regridder(ds, obs_grid, method, periodic=True, reuse_weights=weights_flag)
        weights_flag = True # Set true for following loops

        # Add NaNs to empty rows of matrix (forces any target cell with ANY source cells containing NaN to be NaN)
        regridder = esio.add_matrix_NaNs(regridder)

        # Regrid variable
        var_out = regridder(ds[cvar])

        # Expand dims
        var_out = esio.expand_to_sipn_dims(var_out)
        
        #test_plot()

        # # Save regridded to netcdf file
        var_out.to_netcdf(f_out)
        var_out = None # Memory clean up
        print('Saved ', f_out)
    # Clean up
    if weights_flag:
        regridder.clean_weight_file()  # clean-up
# Out:
# Regridding  bom ...
# Found  15  files.
# Updating all files...
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-02-01 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Create weight file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2018_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-01-01 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_01_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 8, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-02-02 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-03-02 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_03_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-04-02 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_04_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 8, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-05-04 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_05_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-06-01 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_06_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-07-02 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_07_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-08-03 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_08_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-09-03 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_09_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-10-01 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_10_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-11-02 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_11_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 9, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-12-03 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2017_12_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 8, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-01-04 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2018_01_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 62, initial_time0_hours: 3, lat_0: 72, lon_0: 144)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-03-01 ...
#   * lat_0                    (lat_0) float32 88.09951 85.63759 83.161125 ...
#   * lon_0                    (lon_0) float32 0.0 2.5 5.0 7.5 10.0 12.5 15.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GGA0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_72x144_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/bom/forecast/sipn_nc/bom_2018_03_Stereo.nc
# Remove file bilinear_72x144_304x448_peri.nc
# Regridding  cma ...
# Found  15  files.
# Updating all files...
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-02-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Create weight file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2018_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 8, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-03-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2018_03_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-01-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_01_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 28, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-02-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-03-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_03_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-04-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_04_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-05-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_05_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-06-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_06_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-07-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_07_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-08-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_08_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-09-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_09_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-10-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_10_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-11-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_11_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-12-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2017_12_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-01-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/cma/forecast/sipn_nc/cma_2018_01_Stereo.nc
# Remove file bilinear_121x240_304x448_peri.nc
# Regridding  ecmwf ...
# Found  14  files.
# Updating all files...
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-02-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Create weight file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2018_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-01-02 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_01_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 8, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-02-02 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-03-02 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_03_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-04-03 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_04_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-05-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_05_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-06-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_06_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-07-03 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_07_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-08-03 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_08_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 8, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-09-04 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_09_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-10-02 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_10_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-11-02 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_11_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 8, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-12-04 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2017_12_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 46, initial_time0_hours: 9, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-01-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/ecmwf/forecast/sipn_nc/ecmwf_2018_01_Stereo.nc
# Remove file bilinear_121x240_304x448_peri.nc
# Regridding  hcmr ...
# Found  15  files.
# Updating all files...
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 5, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-02-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Create weight file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2018_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 4, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-01-04 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2017_01_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 4, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-02-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2017_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 5, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-03-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2017_03_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 4, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-04-05 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2017_04_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 5, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-05-03 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2017_05_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 4, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-06-08 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2017_06_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 4, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-07-06 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2017_07_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 5, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-08-03 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2017_08_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 4, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-09-07 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/hcmr/forecast/sipn_nc/hcmr_2017_09_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 61, initial_time0_hours: 4, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-10-05 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
# ...
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/eccc/forecast/sipn_nc/eccc_2017_11_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 32, initial_time0_hours: 4, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-12-07 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/eccc/forecast/sipn_nc/eccc_2017_12_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 32, initial_time0_hours: 4, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-01-04 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/eccc/forecast/sipn_nc/eccc_2018_01_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 32, initial_time0_hours: 2, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-03-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/eccc/forecast/sipn_nc/eccc_2018_03_Stereo.nc
# Remove file bilinear_121x240_304x448_peri.nc
# Regridding  kma ...
# Found  15  files.
# Updating all files...
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-02-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Create weight file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2018_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 8, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-03-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2018_03_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-01-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_01_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 28, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-02-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_02_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-03-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_03_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-04-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_04_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-05-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_05_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-06-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_06_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-07-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_07_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-08-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_08_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-09-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_09_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-10-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_10_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-11-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_11_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2017-12-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2017_12_Stereo.nc
# <xarray.Dataset>
# Dimensions:                  (forecast_time0: 60, initial_time0_hours: 31, lat_0: 121, lon_0: 240)
# Coordinates:
#   * initial_time0_hours      (initial_time0_hours) datetime64[ns] 2018-01-01 ...
#   * lat_0                    (lat_0) float32 90.0 88.5 87.0 85.5 84.0 82.5 ...
#   * lon_0                    (lon_0) float32 0.0 1.5 3.0 4.5 6.0 7.5 9.0 ...
#   * forecast_time0           (forecast_time0) timedelta64[ns] 1 days 2 days ...
# Data variables:
#     ICEC_P11_L1_GLL0_avg24h  (initial_time0_hours, forecast_time0, lat_0, lon_0) float32 ...
#     initial_time0_encoded    (initial_time0_hours) float64 ...
#     initial_time0            (initial_time0_hours) |S0 ...
# HACK to remove init_time not inside this current month
# Reuse existing file: bilinear_121x240_304x448_peri.nc
# Saved  /home/disk/sipn/nicway/data/model/kma/forecast/sipn_nc/kma_2018_01_Stereo.nc
# Remove file bilinear_121x240_304x448_peri.nc

# %%
# Out:
# <xarray.DataArray 'init_time' (init_time: 31)>
# array(['2018-01-01T00:00:00.000000000', '2018-01-02T00:00:00.000000000',
#        '2018-01-03T00:00:00.000000000', '2018-01-04T00:00:00.000000000',
#        '2018-01-05T00:00:00.000000000', '2018-01-06T00:00:00.000000000',
#        '2018-01-07T00:00:00.000000000', '2018-01-08T00:00:00.000000000',
#        '2018-01-09T00:00:00.000000000', '2018-01-10T00:00:00.000000000',
#        '2018-01-11T00:00:00.000000000', '2018-01-12T00:00:00.000000000',
#        '2018-01-13T00:00:00.000000000', '2018-01-14T00:00:00.000000000',
#        '2018-01-15T00:00:00.000000000', '2018-01-16T00:00:00.000000000',
#        '2018-01-17T00:00:00.000000000', '2018-01-18T00:00:00.000000000',
#        '2018-01-19T00:00:00.000000000', '2018-01-20T00:00:00.000000000',
#        '2018-01-21T00:00:00.000000000', '2018-01-22T00:00:00.000000000',
#        '2018-01-23T00:00:00.000000000', '2018-01-24T00:00:00.000000000',
#        '2018-01-25T00:00:00.000000000', '2018-01-26T00:00:00.000000000',
#        '2018-01-27T00:00:00.000000000', '2018-01-28T00:00:00.000000000',
#        '2018-01-29T00:00:00.000000000', '2018-01-30T00:00:00.000000000',
#        '2018-01-31T00:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * init_time  (init_time) datetime64[ns] 2018-01-01 2018-01-02 2018-01-03 ...
# Attributes:
#     long_name:  initial time
