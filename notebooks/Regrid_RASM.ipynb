# %%
'''

This code is part of the SIPN2 project focused on improving sub-seasonal to seasonal predictions of Arctic Sea Ice. 
If you use this code for a publication or presentation, please cite the reference in the README.md on the
main page (https://github.com/NicWayand/ESIO). 

Questions or comments should be addressed to nicway@uw.edu

Copyright (c) 2018 Nic Wayand

GNU General Public License v3.0


'''

# Standard Imports
# %matplotlib inline
# %load_ext autoreload
# %autoreload
import matplotlib
import scipy
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import numpy as np
import pandas as pd
import xarray as xr
import xesmf as xe
import os
import glob
import seaborn as sns
import warnings
import datetime
warnings.simplefilter(action='ignore', category=FutureWarning)

# ESIO Imports

from esio import EsioData as ed
from esio import import_data

# %%
# General plotting settings
sns.set_style('whitegrid')
sns.set_context("talk", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
E = ed.EsioData.load()
# Directories
all_models=['rasmesrl']
runType='forecast'
updateall = False

# %%
stero_grid_file = E.obs['NSIDC_0051']['grid']
obs_grid = import_data.load_grid_info(stero_grid_file, model='NSIDC')
# Ensure latitude is within bounds (-90 to 90)
# Have to do this because grid file has 90.000001
obs_grid['lat_b'] = obs_grid.lat_b.where(obs_grid.lat_b < 90, other = 90)

# %%
# Regridding Options
method='nearest_s2d' # ['bilinear', 'conservative', 'nearest_s2d', 'nearest_d2s', 'patch']

# %%
## TODO
# - Get mask
# - Get lat lon bounds

# %%
var_dic = {'aice':'sic','lat':'nj','lon':'ni','TLAT':'lat','TLON':'lon'}

# %%
for model in all_models:
    print('Regridding ', model, '...')
    
    data_dir = E.model[model][runType]['native']
    data_out = E.model[model][runType]['sipn_nc']
    model_grid_file = E.model[model]['grid']
    
    # Files are stored as per time step (about 45 per init_time)
    # First parse files to see what unique init_times we have
    # ARCu0.08_121_2018042112_t0300.nc
    prefix = 'RASM-ESRL'
    all_files = sorted(glob.glob(os.path.join(data_dir, prefix+'*.nc')))
    # Remove init times that started on 12 our (only a few at begining of record)
    all_files = [x for x in all_files if '-12_t' not in x]
    init_times = list(set([s.split('_')[1].split('-00')[0] for s in all_files]))
    
    print("Found ",len(init_times)," initialization times.")
    if updateall:
        print("Updating all files...")
    else:
        print("Only updating new files")


    weights_flag = False # Flag to set up weights have been created

    # Load land/sea mask file
    if os.path.basename(model_grid_file)!='MISSING':
        ds_mask = xr.open_mfdataset(model_grid_file)
    else:
        ds_mask = None

    for cf in init_times:
        # Check if already imported and skip (unless updateall flag is True)
        f_out = os.path.join(data_out, prefix+'_'+cf+'_Stereo.nc') # netcdf file out 
        if not updateall:
            # TODO: Test if the file is openable (not corrupted)
            if os.path.isfile(f_out):
                print("Skipping ", cf, " already imported.")
                continue # Skip, file already imported

        c_files = sorted(glob.glob(os.path.join(data_dir, prefix+'*_'+cf+'*.nc')))
        ds = xr.open_mfdataset(c_files, concat_dim='time', decode_times=False, autoclose=True)

        # Rename variables per esipn guidelines
        ds.rename(var_dic, inplace=True);
        ds = ds.drop('time_bounds')

        # Format times
        ds.coords['init_time'] = np.datetime64(cf)  #np.datetime64(ds.tau.attrs['time_origin'])
        ds.coords['tau'] = ds.tau

        ds.swap_dims({'time':'tau'}, inplace=True)
        ds.rename({'tau':'fore_time'}, inplace=True)
        ds.fore_time.attrs['units'] = 'Forecast offset from initial time'
        ds = ds.drop(['time'])
        ds.coords['fore_time'] = ds.fore_time.astype('timedelta64[h]') 
#         ds.coords['valid_time'] = ds.fore_time + ds.init_time

        # Apply masks (if available)
        if ds_mask:
            print('found mask')
            # land_mask is the fraction of native grid cell that is land
            # (1-land_mask) is fraction ocean
            # Multiply sic by fraction ocean to get actual native grid cell sic
            # Also mask land out where land_mask==1
            ds = ds * (1 - ds_mask.land_mask.where(ds_mask.land_mask<1))

        # Calculate regridding matrix
        regridder = xe.Regridder(ds, obs_grid, method, periodic=False, reuse_weights=weights_flag)
        weights_flag = True # Set true for following loops

        # Add NaNs to empty rows of matrix (forces any target cell with ANY source cells containing NaN to be NaN)
        if method=='conservative':
            regridder = import_data.add_matrix_NaNs(regridder)

        # Regrid variables

        var_list = []
        for cvar in ds.data_vars:
            var_list.append(regridder(ds[cvar]))
        ds_out = xr.merge(var_list)

        # Expand dims
        ds_out = import_data.expand_to_sipn_dims(ds_out)

        # # Save regridded to netcdf file

        ds_out.to_netcdf(f_out)
        ds_out = None # Memory clean up
        ds = None
        print('Saved ', f_out)
# Out:
# Regridding  rasmesrl ...
# Found  261  initialization times.
# Updating all files...
# Create weight file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-12_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-11_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-02_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-11_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-21_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-26_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-13_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-13_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-17_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-10_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-22_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-05_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-25_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-01_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-28_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-23_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-27_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-01_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-12_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-22_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-13_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-04_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-15_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-15_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-29_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-27_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-07_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-02_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-09_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-31_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-16_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-24_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-18_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-25_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-10-31_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-03_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-06_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-14_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-14_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-16_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-23_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-14_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-04_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-10_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-27_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-10-28_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-03_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-05_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-22_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-07_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-07_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-01_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-21_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-03_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-06_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-12_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-26_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-02_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-26_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-25_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-03_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-10_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-20_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-10_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-16_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-17_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-26_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-08_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-20_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-08_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-04_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-10_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-17_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-21_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-19_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-14_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-16_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-28_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-03_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-02_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-07-27_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-16_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-04_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-19_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-21_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-11_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-10_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-25_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-12_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-22_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-01_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-19_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-26_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-19_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-19_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-08_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-23_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-22_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-24_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-01_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-18_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-29_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-18_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-02_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-07_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-15_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-17_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-17_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-23_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-24_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-17_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-05_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-13_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-29_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-24_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-03_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-25_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-16_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-11_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-18_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-22_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-16_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-07-31_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-10_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-15_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-17_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-27_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-06_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-04_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-16_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-08_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-20_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-01_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-05_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-04_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-20_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-29_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-23_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-09_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-21_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-09_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-29_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-27_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-30_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-18_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-26_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-09_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-05_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-17_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-14_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-21_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-14_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-28_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-28_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-01_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-06_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-24_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-06_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-20_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-19_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-21_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-17_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-20_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-07_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-07_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-26_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-10_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-05_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-03_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-20_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-30_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-27_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-09_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-03_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-16_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-27_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-13_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-10-30_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-15_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-30_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-18_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-02_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-05_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-25_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-15_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-18_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-13_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-19_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-30_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-28_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-18_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-22_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-09_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-02_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-04_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-17_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-25_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-31_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-12_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-06_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-11_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-08_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-07_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-19_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-08_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-06_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-08_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-07_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-06_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-05_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-18_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-13_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-05_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-25_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-30_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-21_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-18_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-11_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-13_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-31_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-14_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-14_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-11-10_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-23_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-29_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-11_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-30_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-22_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-23_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-26_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-11_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-09_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-16_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-12_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-07-29_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-19_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-24_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-24_Stereo.nc
# Reuse existing file: nearest_s2d_404x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2016-10-29_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-01_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-02-24_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-22_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-23_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-24_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-15_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-21_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-14_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-06_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-12_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-08-14_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-19_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-28_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-12-13_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-04-20_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-05-09_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-11-12_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-15_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-09-04_Stereo.nc
# Reuse existing file: nearest_s2d_432x384_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2017-10-28_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-20_Stereo.nc
# Reuse existing file: nearest_s2d_464x420_304x448.nc
# Saved  /home/disk/sipn/nicway/data/model/rasmesrl/forecast/sipn_nc/RASM-ESRL_2018-03-04_Stereo.nc

# %%
# Clean up
if weights_flag:
    regridder.clean_weight_file()  # clean-up
# Out:
# Remove file nearest_s2d_464x420_304x448.nc

# %% [markdown]
# # Plotting

# %%
# sic_all = xr.open_mfdataset(f_out)

# # Set up plotting info
# cmap_sic = matplotlib.colors.ListedColormap(sns.color_palette("Blues", 10))
# cmap_sic.set_bad(color = 'red')

# # Plot original projection
# plt.figure(figsize=(20,10))
# ax1 = plt.axes(projection=ccrs.PlateCarree())
# ds_p = ds.sic.isel(fore_time=8)
# ds_p.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
#                                  vmin=0, vmax=1,
#                                  cmap=matplotlib.colors.ListedColormap(sns.color_palette("Blues", 10)),
#                     transform=ccrs.PlateCarree());
# ax1.set_extent([-180, 180, -90, 90], crs=ccrs.PlateCarree())
# gl = ax1.gridlines(crs=ccrs.PlateCarree(), linestyle='-')
# gl.xlabels_bottom = True
# gl.ylabels_left = True
# gl.xformatter = LONGITUDE_FORMATTER
# gl.yformatter = LATITUDE_FORMATTER
# ax1.coastlines(linewidth=0.75, color='black', resolution='50m');

# # Plot SIC on target projection
# (f, ax1) = ice_plot.polar_axis()
# ds_p.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
#                                      transform=ccrs.PlateCarree(),
#                                      cmap=cmap_sic)
# ax1.set_title('Original Grid')

# # Plot SIC on target projection
# (f, ax1) = ice_plot.polar_axis()
# ds_p2 = sic_all.sic.isel(init_time=0).isel(fore_time=8).isel(ensemble=0)
# ds_p2.plot.pcolormesh(ax=ax1, x='lon', y='lat', 
#                                      transform=ccrs.PlateCarree(),
#                                      cmap=cmap_sic)
# ax1.set_title('Target Grid')
