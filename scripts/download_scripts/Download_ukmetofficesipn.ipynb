# %%
'''

This code is part of the SIPN2 project focused on improving sub-seasonal to seasonal predictions of Arctic Sea Ice. 
If you use this code for a publication or presentation, please cite the reference in the README.md on the
main page (https://github.com/NicWayand/ESIO). 

Questions or comments should be addressed to nicway@uw.edu

Copyright (c) 2018 Nic Wayand

GNU General Public License v3.0


'''

from ecmwfapi import ECMWFDataServer
import datetime
import os

# Configuration info about this model
prefix = "ukmetofficesipn"
data_dir = r'/home/disk/sipn/nicway/data/model/ukmetofficesipn/forecast'
native = os.path.join(data_dir, 'native')

if not os.path.exists(native):
    os.makedirs(native)

os.chdir(native)

# %%
# Download a single day
# This dataset is available with 48 hour delay.
day = datetime.datetime.now()

server = ECMWFDataServer()
server.retrieve({
    "class": "c3",
    "dataset": "c3s_seasonal",
    "date": day.strftime("%Y-%m-%d"),
    "expver": "1",
    "levtype": "sfc",
    "method": "1",
    "number": "1/2",
    "origin": "egrr",
    "param": "31.128/144.128",
    "step": "...",
    "stream": "mmsf",
    "system": "12",
    "time": "00:00:00",
    "type": "fc",
    "format": "netcdf",
    "target":  prefix+day.strftime("%Y-%m-%d")+"_00_12.nc",
})
# Out:
# 2018-03-15 11:38:42 ECMWF API python library 1.5.0
# 2018-03-15 11:38:42 ECMWF API at https://api.ecmwf.int/v1
# 2018-03-15 11:38:42 Welcome Nic Wayand
# 2018-03-15 11:38:43 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Web-API+Troubleshooting or contact servicedesk@ecmwf.int
# 2018-03-15 11:38:43 In case of delays, please check  service activity page http://apps.ecmwf.int/webapi-activity/
# 2018-03-15 11:38:44 Request submitted
# 2018-03-15 11:38:44 Request id: 5aaabdb4de6efef9f7cb4e51
# 2018-03-15 11:38:44 Request is queued
# 2018-03-15 13:49:23 Request is active
# Calling '['nice', 'mars', '/tmp/tmp-_mars7_Fc3l.req']'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20180315.204926 - Welcome to MARS with ecCodes + ODB
# mars - INFO   - 20180315.204926 - MARS Client build stamp: 20171030172725
# mars - INFO   - 20180315.204926 - MARS Client version: 6.19.0
# mars - INFO   - 20180315.204926 - EMOSLIB version: 452
# mars - INFO   - 20180315.204926 - Using ecCodes version 2.5.1
# mars - INFO   - 20180315.204926 - Using odb_api version: 0.15.6 (file format version: 0.5)
# mars - INFO   - 20180315.204926 - Maximum retrieval size is 30.00 G
# retrieve,origin=egrr,stream=mmsf,levtype=sfc,number=1/2,expver=0001,system=12,padding=0,method=1,step=...,param=31.128/144.128,time=00:00:00,date=2018-03-15,type=fc,class=c3mars - INFO   - 20180315.204926 - Automatic split by date is on
#
# mars - INFO   - 20180315.204926 - Processing request 1
#
# RETRIEVE,
#     CLASS      = C3,
#     TYPE       = FC,
#     STREAM     = MMSF,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = SFC,
#     PARAM      = 31.128/144.128,
#     TIME       = 0000,
#     STEP       = ...,
#     NUMBER     = 1/2,
#     DOMAIN     = G,
#     ORIGIN     = EGRR,
#     SYSTEM     = 12,
#     METHOD     = 1,
#     PADDING    = 0,
#     DATE       = 20180315
#
# mars - INFO   - 20180315.204926 - Web API request id: 5aaabdb4de6efef9f7cb4e51
# mars - INFO   - 20180315.204927 - Verify schedule:  wall: 1 sec
# mars - ERROR  - 20180315.204927 - Data not yet available. Scheduled after 14 days at 12:00:00, (12:00:00)
# mars - ERROR  - 20180315.204927 - User request matches the following schedule rule:
# mars - ERROR  - 20180315.204927 -       DATE = 20180315
# mars - ERROR  - 20180315.204927 -       TIME = 0000
# mars - ERROR  - 20180315.204927 -       RELEASE = 12:00:00
# mars - INFO   - 20180315.204927 - Memory used: 16.73 Mbyte(s)
# mars - ERROR  - 20180315.204927 - Some errors reported
# ---------------------------------------------------------------------------
# APIException                              Traceback (most recent call last)
# <ipython-input-2-44aec211e1df> in <module>()
#      34     "type": "fc",
#      35     "format": "netcdf",
# ---> 36     "target":  prefix+day.strftime("%Y-%m-%d")+"_00_12.nc",
#      37 })
#
# ~/.local/lib/python3.6/site-packages/ecmwfapi/api.py in retrieve(self, req)
#     518         dataset = req.get("dataset")
#     519         c = APIRequest(self.url, "datasets/%s" % (dataset,), self.email, self.key, self.trace, verbose=self.verbose)
# --> 520         c.execute(req, target)
#     521
#     522 ###############################################################################
#
# ~/.local/lib/python3.6/site-packages/ecmwfapi/api.py in execute(self, request, target)
#     461                 status = self.connection.status
#     462                 self.log("Request is %s" % (status, ))
# --> 463             self.connection.wait()
#     464
#     465         if self.connection.status != status:
#
# ~/.local/lib/python3.6/site-packages/ecmwfapi/api.py in wait(self)
#     358             print("Sleeping %s second(s)" % (self.retry))
#     359         time.sleep(self.retry)
# --> 360         self.call(self.location, None, "GET")
#     361
#     362     def ready(self):
#
# ~/.local/lib/python3.6/site-packages/ecmwfapi/api.py in wrapped(self, *args, **kwargs)
#     138         while tries > 0:
#     139             try:
# --> 140                 return func(self, *args, **kwargs)
#     141             except HTTPError as e:
#     142                 if self.verbose:
#
# ~/.local/lib/python3.6/site-packages/ecmwfapi/api.py in call(self, url, payload, method)
#     338
#     339         if "error" in self.last:
# --> 340             raise APIException("ecmwf.API error 1: %s" % (self.last["error"],))
#     341
#     342         if error:
#
# APIException: 'ecmwf.API error 1: ERROR 99 (MARS_BAD_REQUEST): Some errors reported'

# %%
server = ECMWFDataServer()
server.retrieve({     "class": "c3",
                 "dataset": "c3s_seasonal",
                 "date": "2018-02-01",     
                 "expver": "1",     
                 "levtype": "sfc",     
                 "method": "1",     
                 "number": "1",     
                 "origin": "egrr",     
                 "param": "31.128",     
                 "step": "0/6/12",     
                 "stream": "mmsf",     
                 "system": "12",     
                 "time": "00:00:00",     
                 "type": "fc",     
                 "target": "2018_02_01_small.grib",
                 "expect": "any", })
# Out:
# 2018-03-20 09:35:38 ECMWF API python library 1.5.0
# 2018-03-20 09:35:38 ECMWF API at https://api.ecmwf.int/v1
# 2018-03-20 09:35:38 Welcome Nic Wayand
# 2018-03-20 09:35:39 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Web-API+Troubleshooting or contact servicedesk@ecmwf.int
# 2018-03-20 09:35:39 In case of delays, please check  service activity page http://apps.ecmwf.int/webapi-activity/
# 2018-03-20 09:35:40 Request submitted
# 2018-03-20 09:35:40 Request id: 5ab1385c3248b25bda44987f
# 2018-03-20 09:35:40 Request is queued
# Calling '['nice', 'mars', '/tmp/tmp-_marsMYpJ71.req']'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20180320.182647 - Welcome to MARS with ecCodes + ODB
# mars - INFO   - 20180320.182647 - MARS Client build stamp: 20171030172725
# mars - INFO   - 20180320.182647 - MARS Client version: 6.19.0
# mars - INFO   - 20180320.182647 - EMOSLIB version: 452
# mars - INFO   - 20180320.182647 - Using ecCodes version 2.5.1
# mars - INFO   - 20180320.182647 - Using odb_api version: 0.15.6 (file format version: 0.5)
# mars - INFO   - 20180320.182647 - Maximum retrieval size is 30.00 G
# retrieve,origin=egrr,stream=mmsf,levtype=sfc,system=12,expver=0001,number=1,padding=0,method=1,step=0/6/12,expect=any,time=00:00:00,date=2018-02-01,param=31.128,type=fc,class=c3mars - INFO   - 20180320.182647 - Automatic split by date is on
#
# mars - INFO   - 20180320.182647 - Processing request 1
#
# RETRIEVE,
#     CLASS      = C3,
#     TYPE       = FC,
#     STREAM     = MMSF,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = SFC,
#     PARAM      = 31.128,
#     TIME       = 0000,
#     STEP       = 0/6/12,
#     NUMBER     = 1,
#     DOMAIN     = G,
#     ORIGIN     = EGRR,
#     SYSTEM     = 12,
#     METHOD     = 1,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 20180201
#
# mars - INFO   - 20180320.182647 - Web API request id: 5ab1385c3248b25bda44987f
# mars - INFO   - 20180320.182648 - Requesting any number of fields (request describes 3)
# mars - INFO   - 20180320.182648 - Calling mars on 'marser', callback on 33673
# mars - INFO   - 20180320.182648 - Server task is 107 [marser]
# mars - INFO   - 20180320.182648 - Request cost: 0 field,  [marser]
# mars - WARN   - 20180320.182648 - Data not found [marser]
# mars - WARN   - 20180320.182648 - No data, but EXPECT was provided
# mars - INFO   - 20180320.182648 - Memory used: 22.60 Mbyte(s)
# mars - INFO   - 20180320.182648 - No errors reported
# Process '['nice', 'mars', '/tmp/tmp-_marsMYpJ71.req']' finished
# 2018-03-20 11:28:01 Request is complete
# 2018-03-20 11:28:01 Transfering 0 byte into 2018_02_01_small.grib
# 2018-03-20 11:28:01 From https://stream.ecmwf.int/data/atls14/data/data03/scratch/_mars-atls14-98f536083ae965b31b0d04811be6f4c6-rHlft4.grib
# 2018-03-20 11:28:02 Transfer rate 0 byte/s
