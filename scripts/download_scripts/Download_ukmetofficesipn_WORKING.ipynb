# %%
from ecmwfapi import ECMWFDataServer
import datetime
import os

# Configuration info about this model
prefix = "ukmetofficesipn"
data_dir = r'/home/disk/sipn/nicway/data/model/ukmetofficesipn/forecast'
native = os.path.join(data_dir, 'native')

if not os.path.exists(native):
    os.makedirs(native)

os.chdir(native)

# %%
server = ECMWFDataServer()
server.retrieve({     "class": "c3",
                 "dataset": "c3s_seasonal",
                 "date": "2018-02-02",     
                 "expver": "1",     
                 "levtype": "sfc",     
                 "method": "1",     
                 "number": "1/2",     
                 "origin": "egrr",     
                 "param": "31.128",     
                 "step": "...",     
                 "stream": "mmsf",     
                 "system": "12",     
                 "time": "00:00:00",     
                 "type": "fc",     
                 "target": "2018_02_02.grib",
                 "expect": "any", })
# Out:
# 2018-03-24 13:38:52 ECMWF API python library 1.5.0
# 2018-03-24 13:38:52 ECMWF API at https://api.ecmwf.int/v1
# 2018-03-24 13:38:53 Welcome Nic Wayand
# 2018-03-24 13:38:54 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Web-API+Troubleshooting or contact servicedesk@ecmwf.int
# 2018-03-24 13:38:54 In case of delays, please check  service activity page http://apps.ecmwf.int/webapi-activity/
# 2018-03-24 13:38:55 Request submitted
# 2018-03-24 13:38:55 Request id: 5ab6b75ff7414d9f15571227
# 2018-03-24 13:38:55 Request is queued
# 2018-03-24 13:39:55 Request is active
# Calling 'nice mars /tmp/tmp-_marsp5rs3P.req'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# ...

# %%
# Download a single day
# This dataset is available with 15 day delay.
day = datetime.datetime.now() -  datetime.timedelta(days=16)

server = ECMWFDataServer()
server.retrieve({
    "class": "c3",
    "dataset": "c3s_seasonal",
    "date": day.strftime("%Y-%m-%d"),
    "expver": "1",
    "levtype": "sfc",
    "method": "1",
    "number": "1/2",
    "origin": "egrr",
    "param": "31.128/144.128",
    "step": "...",
    "stream": "mmsf",
    "system": "12",
    "time": "00:00:00",
    "type": "fc",
    "grid": "1.0/1.0",
    "format": "netcdf",
    "target":  "big_test.nc",
})
